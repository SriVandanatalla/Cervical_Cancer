# %% [markdown]
# # How to Train YOLOv9 on a Custom Dataset
# ---
#
# [![Roboflow](https://raw.githubusercontent.com/roboflow-ai/notebooks/main/assets/badges/roboflow-blogpost.svg)](https://blog.roboflow.com/train-yolov9-model/)
# [![GitHub](https://badges.aleen42.com/src/github.svg)](https://github.com/WongKinYiu/yolov9)
# [![YouTube](https://badges.aleen42.com/src/youtube.svg)](https://youtu.be/XHT2c8jT3Bc)
# [![arXiv](https://img.shields.io/badge/arXiv-2402.13616-b31b1b.svg)](https://arxiv.org/pdf/2402.13616.pdf)

# %% [markdown]
# ## Before you start
#
# Let's make sure that we have access to GPU. We can use `nvidia-smi` command to do that. In case of any problems navigate to `Edit` -> `Notebook settings` -> `Hardware accelerator`, set it to `GPU`, and then click `Save`.

# %%
# !nvidia-smi
# Out:
# Sun Jun 23 09:38:41 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   41C    P8               9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |  No running processes found                                                           |
# +---------------------------------------------------------------------------------------+

# %% [markdown]
# **NOTE:** To make it easier for us to manage datasets, images and models we create a `HOME` constant.

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /content/yolov99

# %% [markdown]
# ## Clone and Install

# %% [markdown]
# **NOTE:** YOLOv9 is very new. At the moment, we recommend using a fork of the main repository. The `detect.py` script contains a bug that prevents inference. This bug is patched in the fork.

# %%
# !git clone https://github.com/SkalskiP/yolov9.git
# %cd yolov9
# !pip install -r requirements.txt -q
# Out:
# Cloning into 'yolov9'...
# remote: Enumerating objects: 325, done.
# remote: Counting objects: 100% (218/218), done.
# remote: Compressing objects: 100% (62/62), done.
# remote: Total 325 (delta 159), reused 156 (delta 156), pack-reused 107
# Receiving objects: 100% (325/325), 2.23 MiB | 26.01 MiB/s, done.
# Resolving deltas: 100% (165/165), done.
# /content/yolov99/yolov9

# %% [markdown]
# **NOTE:** Let's install the [`roboflow`](https://pypi.org/project/roboflow) package, which we will use to download our dataset from [Roboflow Universe](https://universe.roboflow.com/).

# %%
# !pip install -q roboflow

# %% [markdown]
# ## Download model weights

# %% [markdown]
# **NOTE:** In the YOLOv9 paper, versions `yolov9-s` and `yolov9-m` are also mentioned, but the weights for these models are not yet available in the YOLOv9 [repository](https://github.com/WongKinYiu/yolov9).

# %%
# !wget -P {HOME}/weights -q https://github.com/WongKinYiu/yolov9/releases/download/v0.1/yolov9-c.pt
# !wget -P {HOME}/weights -q https://github.com/WongKinYiu/yolov9/releases/download/v0.1/yolov9-e.pt
# !wget -P {HOME}/weights -q https://github.com/WongKinYiu/yolov9/releases/download/v0.1/gelan-c.pt
# !wget -P {HOME}/weights -q https://github.com/WongKinYiu/yolov9/releases/download/v0.1/gelan-e.pt

# %%
# !ls -la {HOME}/weights
# Out:
# total 402444
# drwxr-xr-x 2 root root      4096 Jun 23 08:42 .
# drwxr-xr-x 1 root root      4096 Jun 23 08:42 ..
# -rw-r--r-- 1 root root  51508261 Feb 18 12:36 gelan-c.pt
# -rw-r--r-- 1 root root 117203713 Feb 18 12:36 gelan-e.pt
# -rw-r--r-- 1 root root 103153312 Feb 18 12:36 yolov9-c.pt
# -rw-r--r-- 1 root root 140217688 Feb 18 12:36 yolov9-e.pt

# %% [markdown]
# ## Download example data

# %% [markdown]
# **NOTE:** If you want to run inference using your own file as input, simply upload image to Google Colab and update `SOURCE_IMAGE_PATH` with the path leading to your file.

# %%
# !wget -P {HOME}/data -q https://media.roboflow.com/notebooks/examples/dog.jpeg

# %%
SOURCE_IMAGE_PATH = f"{HOME}/dog.jpeg"

# %% [markdown]
# ## Detection with pre-trained COCO model

# %% [markdown]
# ### gelan-c

# %%
# !python detect.py --weights {HOME}/weights/gelan-c.pt --conf 0.1 --source {HOME}/data/dog.jpeg --device 0
# Out:
# detect: weights=['/content/weights/gelan-c.pt'], source=/content/data/dog.jpeg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.1, iou_thres=0.45, max_det=1000, device=0, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 1e33dbb Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# Model summary: 467 layers, 25472640 parameters, 0 gradients, 102.8 GFLOPs
# image 1/1 /content/data/dog.jpeg: 640x384 1 person, 1 car, 1 dog, 1 handbag, 125.9ms
# Speed: 0.4ms pre-process, 125.9ms inference, 638.9ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp

# %% [markdown]
# **NOTE:** By default, the results of each subsequent inference sessions are saved in `{HOME}/yolov9/runs/detect/`, in directories named `exp`, `exp2`, `exp3`, ... You can override this behavior by using the `--name` parameter.

# %%
from IPython.display import Image

Image(filename=f"{HOME}/yolov9/runs/detect/exp/dog.jpeg", width=600)

# %% [markdown]
# ## yolov9-e

# %%
# !python detect.py --weights {HOME}/weights/yolov9-e.pt --conf 0.1 --source {HOME}/data/dog.jpeg --device 0
# Out:
# detect: weights=['/content/yolov99/weights/yolov9-e.pt'], source=/content/yolov99/data/dog.jpeg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.1, iou_thres=0.45, max_det=1000, device=0, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 1e33dbb Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# Model summary: 1119 layers, 69470144 parameters, 0 gradients, 244.0 GFLOPs
# image 1/1 /content/yolov99/data/dog.jpeg: 640x384 1 person, 1 car, 1 dog, 1 backpack, 1 handbag, 159.8ms
# Speed: 0.6ms pre-process, 159.8ms inference, 516.0ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp

# %%
from IPython.display import Image

Image(filename=f"{HOME}/yolov9/runs/detect/exp2/dog.jpeg", width=600)

# %% [markdown]
# ## Authenticate and Download the Dataset

# %% [markdown]
# **NOTE:** The dataset must be saved inside the `{HOME}/yolov9` directory, otherwise, the training will not succeed.

# %%
# %cd {HOME}/yolov9
# Out:
# /content/yolov99/yolov9

# %% [markdown]
# **NOTE:** In this tutorial, I will use the [football-players-detection](https://universe.roboflow.com/roboflow-jvuqo/football-players-detection-3zvbc) dataset. Feel free to replace it with your dataset in YOLO format or use another dataset available on [Roboflow Universe](https://universe.roboflow.com). Additionally, if you plan to deploy your model to Roboflow after training, make sure you are the owner of the dataset and that no model is associated with the version of the dataset you are going to training on.

# %%
import roboflow
roboflow.login()
rf = roboflow.Roboflow()
project = rf.workspace("cancer-anotation").project("paps-smear-cells")
version = project.version(4)
dataset = version.download("yolov9")
# Out:
# You are already logged into Roboflow. To make a different login,run roboflow.login(force=True).
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in Paps-Smear-Cells-4 to yolov9:: 100%|██████████| 65484/65484 [00:03<00:00, 20867.08it/s]
# Extracting Dataset Version Zip to Paps-Smear-Cells-4 in yolov9:: 100%|██████████| 4020/4020 [00:00<00:00, 6776.07it/s]

# %% [markdown]
# ## Train Custom Model

# %%
# %cd {HOME}/yolov9

# !python train.py \
--batch 16 --epochs 25 --img 640 --device 0 --min-items 0 --close-mosaic 15 \
--data {dataset.location}/data.yaml \
--weights {HOME}/weights/gelan-c.pt \
--cfg models/detect/gelan-c.yaml \
--hyp hyp.scratch-high.yaml
# Out:
# /content/yolov99/yolov9
# 2024-06-23 09:43:57.633913: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-06-23 09:43:57.633964: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-06-23 09:43:57.635399: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-06-23 09:43:57.642598: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-06-23 09:43:58.893168: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# train: weights=/content/yolov99/weights/gelan-c.pt, cfg=models/detect/gelan-c.yaml, data=/content/yolov99/yolov9/Paps-Smear-Cells-4/data.yaml, hyp=hyp.scratch-high.yaml, epochs=25, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=0, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, flat_cos_lr=False, fixed_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, min_items=0, close_mosaic=15, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# YOLOv5 🚀 1e33dbb Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
#
# hyperparameters: lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, cls_pw=1.0, dfl=1.5, obj_pw=1.0, iou_t=0.2, anchor_t=5.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.9, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.15, copy_paste=0.3
# ClearML: run 'pip install clearml' to automatically track, visualize and remotely train YOLO 🚀 in ClearML
# Comet: run 'pip install comet_ml' to automatically track and visualize YOLO 🚀 runs in Comet
# TensorBoard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
# Overriding model.yaml nc=80 with nc=4
#
#                  from  n    params  module                                  arguments
#   0                -1  1      1856  models.common.Conv                      [3, 64, 3, 2]
#   1                -1  1     73984  models.common.Conv                      [64, 128, 3, 2]
#   2                -1  1    212864  models.common.RepNCSPELAN4              [128, 256, 128, 64, 1]
#   3                -1  1    164352  models.common.ADown                     [256, 256]
#   4                -1  1    847616  models.common.RepNCSPELAN4              [256, 512, 256, 128, 1]
#   5                -1  1    656384  models.common.ADown                     [512, 512]
#   6                -1  1   2857472  models.common.RepNCSPELAN4              [512, 512, 512, 256, 1]
#   7                -1  1    656384  models.common.ADown                     [512, 512]
#   8                -1  1   2857472  models.common.RepNCSPELAN4              [512, 512, 512, 256, 1]
#   9                -1  1    656896  models.common.SPPELAN                   [512, 512, 256]
#  10                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  11           [-1, 6]  1         0  models.common.Concat                    [1]
#  12                -1  1   3119616  models.common.RepNCSPELAN4              [1024, 512, 512, 256, 1]
#  13                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  14           [-1, 4]  1         0  models.common.Concat                    [1]
#  15                -1  1    912640  models.common.RepNCSPELAN4              [1024, 256, 256, 128, 1]
#  16                -1  1    164352  models.common.ADown                     [256, 256]
#  17          [-1, 12]  1         0  models.common.Concat                    [1]
#  18                -1  1   2988544  models.common.RepNCSPELAN4              [768, 512, 512, 256, 1]
#  19                -1  1    656384  models.common.ADown                     [512, 512]
#  20           [-1, 9]  1         0  models.common.Concat                    [1]
#  21                -1  1   3119616  models.common.RepNCSPELAN4              [1024, 512, 512, 256, 1]
#  22      [15, 18, 21]  1   5493724  models.yolo.DDetect                     [4, [256, 512, 512]]
# gelan-c summary: 621 layers, 25440156 parameters, 25440140 gradients, 103.2 GFLOPs
#
# Transferred 931/937 items from /content/yolov99/weights/gelan-c.pt
# AMP: checks passed ✅
# optimizer: SGD(lr=0.01) with parameter groups 154 weight(decay=0.0), 161 weight(decay=0.0005), 160 bias
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# train: Scanning /content/yolov99/yolov9/Paps-Smear-Cells-4/train/labels... 1851 images, 0 backgrounds, 0 corrupt: 100% 1851/1851 [00:02<00:00, 890.90it/s]
# train: New cache created: /content/yolov99/yolov9/Paps-Smear-Cells-4/train/labels.cache
# val: Scanning /content/yolov99/yolov9/Paps-Smear-Cells-4/valid/labels... 76 images, 0 backgrounds, 0 corrupt: 100% 76/76 [00:00<00:00, 542.09it/s]
# val: New cache created: /content/yolov99/yolov9/Paps-Smear-Cells-4/valid/labels.cache
# Plotting labels to runs/train/exp/labels.jpg...
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to runs/train/exp
# Starting training for 25 epochs...
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        0/24      13.3G      1.223      1.984      1.398        135        640: 100% 116/116 [01:55<00:00,  1.00it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:02<00:00,  1.34it/s]
#                    all         76        558      0.417      0.446      0.393      0.258
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/24      14.1G      1.052       1.27      1.246        175        640: 100% 116/116 [01:42<00:00,  1.14it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:01<00:00,  1.59it/s]
#                    all         76        558       0.41      0.527      0.479      0.329
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/24      14.1G      1.073      1.247      1.252        178        640: 100% 116/116 [01:40<00:00,  1.15it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:01<00:00,  1.58it/s]
#                    all         76        558      0.451      0.481       0.46      0.298
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/24      14.1G      1.098      1.192      1.245        129        640: 100% 116/116 [01:38<00:00,  1.18it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:02<00:00,  1
[00:00<?, ?it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 2/2 [00:04<00:00,  2.50s/it]
#                    all         38        251      0.555      0.637      0.615      0.446
#                   HSIL         38         99      0.706      0.808      0.774      0.467
#             Koilocytes         38          7      0.409      0.429      0.417      0.296
#                   LSIL         38         42       0.35      0.513      0.394      0.302
#                 Normal         38        103      0.753      0.798      0.873       0.72
# Speed: 0.2ms pre-process, 56.7ms inference, 30.6ms NMS per image at shape (32, 3, 640, 640)
# Results saved to runs/val/exp

# %% [markdown]
# ## Inference with Custom Model

# %%
# !python detect.py \
--img 1280 --conf 0.1 --device 0 \
--weights {HOME}/yolov9/runs/train/exp/weights/best.pt \
--source {dataset.location}/test/images
# Out:
# detect: weights=['/content/yolov9/runs/train/exp/weights/best.pt'], source=/content/yolov9/Deteksi-Abnormal-Sel-5/test/images, data=data/coco128.yaml, imgsz=[1280, 1280], conf_thres=0.1, iou_thres=0.45, max_det=1000, device=0, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 1e33dbb Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# gelan-c summary: 467 layers, 25414044 parameters, 0 gradients, 102.5 GFLOPs
# image 1/37 /content/yolov9/Deteksi-Abnormal-Sel-5/test/images/L-CV-1904662-140353_jpg.rf.300083c0370a88c6d5a5e23965ba064b.jpg: 1280x1280 2 LSILs, 13 Normals, 131.6ms
# image 2/37 /content/yolov9/Deteksi-Abnormal-Sel-5/test/images/N-CV-149562-11009_jpg.rf.e373611b37fea8763c0e993d24b7310d.jpg: 1280x1280 3 LSILs, 7 Normals, 106.8ms
# image 3/37 /content/yolov9/Deteksi-Abnormal-Sel-5/test/images/N-CV-149562-11016_jpg.rf.03b2b9b6df1d8e92592493153857f9d2.jpg: 1280x1280 12 Normals, 106.0ms
# image 4/37 /content/yolov9/Deteksi-Abnormal-Sel-5/test/images/N-CV-149562-11030_jpg.rf.cb23413b423e17d805b6c6b881ab79d2.jpg: 1280x1280 2 HSILs, 1 LSIL, 14 Normals, 105.5ms
# image 5/37 /content/yolov9/Deteksi-Abnormal-Sel-5/test/images/N-CV-149562-11042_jpg.rf.9cef810948649c02883354daa954cc31.jpg: 1280x1280 14 Normals, 105.4ms
# image 6/37 /content/yolov9/Deteksi-Abnormal-Sel-5/test/images/N-CV-149562-11067_jpg.rf.70ec50bdee91266562b4091a2a0cce16.jpg: 1280x1280 5 Normals, 105.3ms
# image 7/37 /content/yolov9/Deteksi-Abnormal-Sel-5/test/images/N-CV-149562-11072_jpg.rf.127ef9bbd125edbbcce443f6344f90d0.jpg: 1280x1280 13 Normals, 105.6ms
# image 8/37 /content/yolov9/Deteksi-Abnormal-Sel-5/test/images/N-CV-149562-11074_jpg.rf.c26f7e79b70c6c6f3979a55c1f41bd64.jpg: 1280x1280 1 HSIL, 1 LSIL, 6 Normals, 105.9ms
# image 9/37 /content/yolov9/Deteksi-Abnormal-Sel-5/test/images/N-CV-149562-11089_jpg.rf.d4749aedd170ac28b97dda5ac801d9d5.jpg: 1280x1280 3 Normals, 105.5ms
# image 10/37 /content/yolov9/Deteksi-Abnormal-Sel-5/test/images/N-CV-149562-11094_jpg.rf.a872cb09bdab295616e09924a96ad564.jpg: 1280x1280 5 Normals, 105.3ms
# image 11/37 /content/yolov9/Deteksi-Abnormal-Sel-5/test/images/N-CV-149562-11098_jpg.rf.ab22fb09f178dd8f0f7ae931b5100659.jpg: 1280x1280 1 Normal, 105.5ms
# image 12/37 /content/yolov9/Deteksi-Abnormal-Sel-5/test/images/N-CV-149562-11100_jpg.rf.4efde220abffc9b56e9d81e6a78f2ccb.jpg: 1280x1280 14 Normals, 105.2ms
# image 13/37 /content/yolov9/Deteksi-Abnormal-Sel-5/test/images/N-CV-149562-11103_jpg.rf.8adcee9200e96fdd4a73679dffb8ae98.jpg: 1280x1280 9 Normals, 105.4ms
# image 14/37 /content/yolov9/Deteksi-Abnormal-Sel-5/test/images/N-CV-149562-11109_jpg.rf.4973ccc23f701465a5f30d7b94ffcb79.jpg: 1280x1280 1 HSIL, 8 Normals, 105.1ms
# image 15/37 /content/yolov9/Deteksi-Abnormal-Sel-5/test/images/N-CV-149562-11114_jpg.rf.53848d0e4b4f903a236d6c83c22f6093.jpg: 1280x1280 7 Normals, 105.7ms
# image 16/37 /content/yolov9/Deteksi-Abnormal-Sel-5/test/images/N-CV-149562-11121_jpg.rf.8cece823994a2ec16ebe878b7657cda8.jpg: 1280x1280 5 Normals, 105.6ms
# image 17/37 /content/yolov9/Deteksi-Abnormal-Sel-5/test/images/N-CV-149562-11123_jpg.rf.0e3de5e95717cd593ac8bd5a9e0a8392.jpg: 1280x1280 1 HSIL, 5 Normals, 106.1ms
# image 18/37 /content/yolov9/Deteksi-Abnormal-Sel-5/test/images/N-CV-149562-11125_jpg.rf.522c5112472a59b541b54941886ed833.jpg: 1280x1280 3 Normals, 105.3ms
# image 19/37 /content/yolov9/Deteksi-Abnormal-Sel-5/test/images/N-CV-149562-11129_jpg.rf.d7c60cd76dfe68c9a2629a4f27fc7a8a.jpg: 1280x1280 7 Normals, 105.8ms
# image 20/37 /content/yolov9/Deteksi-Abnormal-Sel-5/test/images/N-CV-149562-11131_jpg.rf.37478cf57bf49827540440ff0dda0ee7.jpg: 1280x1280 1 HSIL, 16 Normals, 106.3ms
# image 21/37 /content/yolov9/Deteksi-Abnormal-Sel-5/test/images/N-CV-149562-11134_jpg.rf.3dcde94be2d78684328982bba3d64299.jpg: 1280x1280 1 HSIL, 16 Normals, 105.1ms
# image 22/37 /content/yolov9/Deteksi-Abnormal-Sel-5/test/images/N-CV-149594-110002_jpg.rf.cc8a4e367b0b4e9e83cddcc905c2dd35.jpg: 1280x1280 4 Normals, 105.2ms
# image 23/37 /content/yolov9/Deteksi-Abnormal-Sel-5/test/images/N-CV-149594-110003_jpg.rf.06f3f0311dc6652855253e6c7ba26e79.jpg: 1280x1280 8 Normals, 106.6ms
# image 24/37 /content/yolov9/Deteksi-Abnormal-Sel-5/test/images/N-CV-149594-110007_jpg.rf.a8f023a68fa45e083128d4ae84fd7e5e.jpg: 1280x1280 5 Normals, 105.7ms
# image 25/37 /content/yolov9/Deteksi-Abnormal-Sel-5/test/images/N-CV-149594-110010_jpg.rf.319d1097a6e8e9738718413d3b675144.jpg: 1280x1280 1 HSIL, 5 Normals, 106.5ms
# image 26/37 /content/yolov9/Deteksi-Abnormal-Sel-5/test/images/N-CV-149594-110011_jpg.rf.4cb02f533e5186e1d412b50f4ac935e9.jpg: 1280x1280 12 Normals, 105.4ms
# image 27/37 /content/yolov9/Deteksi-Abnormal-Sel-5/test/images/N-CV-149594-110013_jpg.rf.bcd91fcb54e8f6541a5ccada0878bd51.jpg: 1280x1280 1 LSIL, 13 Normals, 105.6ms
# image 28/37 /content/yolov9/Deteksi-Abnormal-Sel-5/test/images/N-CV-149594-110019_jpg.rf.edc99a668867d4d535627940a463fe18.jpg: 1280x1280 13 Normals, 106.5ms
# image 29/37 /content/yolov9/Deteksi-Abnormal-Sel-5/test/images/N-CV-149594-110027_jpg.rf.bf2c0ccf75d99d63694afec4b816bb59.jpg: 1280x1280 15 Normals, 105.6ms
# image 30/37 /content/yolov9/Deteksi-Abnormal-Sel-5/test/images/N-CV-149594-110029_jpg.rf.8cf8fe91071d78a8d3bd7edb3d59c86d.jpg: 1280x1280 15 Normals, 105.4ms
# image 31/37 /content/yolov9/Deteksi-Abnormal-Sel-5/test/images/N-CV-149594-110039_jpg.rf.f16267ca858d3d0d7d6d8fe5391cc201.jpg: 1280x1280 17 Normals, 106.3ms
# image 32/37 /content/yolov9/Deteksi-Abnormal-Sel-5/test/images/N-CV-149594-110044_jpg.rf.2ef5e451e3596ee44451b8e922e837ed.jpg: 1280x1280 14 Normals, 107.8ms
# image 33/37 /content/yolov9/Deteksi-Abnormal-Sel-5/test/images/N-CV-149594-110072_jpg.rf.ef5f788e5954979b338010566ab0ab10.jpg: 1280x1280 15 Normals, 107.8ms
# image 34/37 /content/yolov9/Deteksi-Abnormal-Sel-5/test/images/N-CV-149594-110078_jpg.rf.5f4bdfe9df0c6ba2b0568f239e192562.jpg: 1280x1280 11 Normals, 106.0ms
# image 35/37 /content/yolov9/Deteksi-Abnormal-Sel-5/test/images/N-CV-149594-110079_jpg.rf.785d65454ceee822d2f7df136eb33236.jpg: 1280x1280 1 LSIL, 19 Normals, 106.7ms
# image 36/37 /content/yolov9/Deteksi-Abnormal-Sel-5/test/images/N-CV-149594-110088_jpg.rf.9f801fb2d13e977e4646214b0f69035b.jpg: 1280x1280 11 Normals, 106.0ms
# image 37/37 /content/yolov9/Deteksi-Abnormal-Sel-5/test/images/N-CV-149594-110097_jpg.rf.2cbc89801ef276acd08a8a891c0c9732.jpg: 1280x1280 21 Normals, 106.8ms
# Speed: 2.0ms pre-process, 106.6ms inference, 15.3ms NMS per image at shape (1, 3, 1280, 1280)
# Results saved to runs/detect/exp3

# %% [markdown]
# **NOTE:** Just like behore, the inference results have been saved in the appropriate directory inside `{HOME}/yolov9/runs/detect/`. Let's examine few of those results.

# %%
import glob

from IPython.display import Image, display

for image_path in glob.glob(f'{HOME}/yolov9/runs/detect/exp3/*.jpg')[:2]:
      display(Image(filename=image_path, width=600))

# %% [markdown]
# ## BONUS: Deploy YOLOv9 Model with Inference

# %% [markdown]
# **NOTE:** To deploy the model and display inference results, we will need two additional packages - [`inference`](https://pypi.org/project/inference) and [`supervision`](https://pypi.org/project/supervision). Let's install and import them!

# %%
# !pip install -q inference supervision

# %%
import cv2
import random
import getpass

import supervision as sv

from inference import get_model

# %matplotlib inline

# %% [markdown]
# **NOTE:** Before using your model in Inference, you first need to upload your weights to Roboflow Universe. Ensure to specify the correct `model_type` - `yolov9`, and that the project version matches the version of the dataset you used for training, denoted by `[1]`. In my case, it's `6`.
#
# ![YOLOv9 Benchmark](https://storage.googleapis.com/com-roboflow-marketing/notebooks/examples/upload-roboflow-model.png)

# %%
version.deploy(model_type="yolov9", model_path=f"{HOME}/yolov9/runs/train/exp")
# Out:
# View the status of your deployment at: https://app.roboflow.com/roboflow-jvuqo/football-players-detection-3zvbc/6
# Share your model with the world at: https://universe.roboflow.com/roboflow-jvuqo/football-players-detection-3zvbc/model/6

# %% [markdown]
# **NOTE:** Now we can download our model anywhere using the assigned `model_id` denoted by `[2]`. In my case `football-players-detection-3zvbc/6`. To download the model you will need your [`ROBOFLOW_API_KEY`](https://docs.roboflow.com/api-reference/authentication).

# %%
ROBOFLOW_API_KEY = getpass.getpass()

model = get_model(model_id="football-players-detection-3zvbc/8", api_key=ROBOFLOW_API_KEY)
# Out:
# ··········

# %% [markdown]
# **NOTE:** Let's pick random image from our test subset and detect objects using newly fine-tuned model.

# %%
image_paths = sv.list_files_with_extensions(
    directory=f"{dataset.location}/test/images",
    extensions=['png', 'jpg', 'jpeg']
)
image_path = random.choice(image_paths)
image = cv2.imread(image_path)

result = model.infer(image, confidence=0.1)[0]
detections = sv.Detections.from_inference(result)

# %% [markdown]
# **NOTE:** Finally, let's use supervision and [annotate](https://supervision.roboflow.com/develop/annotators/) our results.

# %%
label_annotator = sv.LabelAnnotator(text_color=sv.Color.BLACK)
bounding_box_annotator = sv.BoundingBoxAnnotator()

annotated_image = image.copy()
annotated_image = bounding_box_annotator.annotate(scene=annotated_image, detections=detections)
annotated_image = label_annotator.annotate(scene=annotated_image, detections=detections)

sv.plot_image(annotated_image)
